# %% [markdown]
# ![solution_registery.png](attachment:5a1dd66e-b0d7-49e5-8cf8-9d7d59da3f80.png)

# %% [markdown]
# # Solution Registry
#
# #### by Joe Eberle started on 05-23-2023 - https://github.com/JoeEberle/ - josepheberle@outlook.com

# %% [markdown]
# A **solution registry** for Artificial Intelligence (AI) busines solutions serves as a centralized database containing names, directories, and brief descriptions of various AI solutions. This registry facilitates easy access to a wide range of AI solutions, allowing businesses and individuals to quickly identify relevant tools for their needs. Moreover, maintaining such a registry ensures up-to-date information on emerging AI technologies, fosters collaboration and knowledge sharing among developers, and streamlines the process of researching and adopting AI solutions. With proper organization and regular updates, the registry offers a comprehensive resource that enhances decision-making and accelerates innovation in the AI ecosystem.

# %%
import os
import schedule
import pandas as pd
import quick_logger as ql
import talking_code as tc 
import file_manager as fm 
from datetime import date, datetime
import time
import zipfile
print(f"Libraries Imported succesfully on {datetime.now().date()} at {datetime.now().time()}")
# Out:
# Libraries Imported succesfully on 2024-04-27 at 17:02:07.655669

# %% [markdown]
# ## Optional Step 0 - Intitiate Configuration Settings and name the overall solution

# %%
import configparser 
config = configparser.ConfigParser()
cfg = config.read('config.ini')  
solution_name = 'solution_registry'

# %% [markdown]
# ## Optional Step 0 - Intitiate Logging and debugging

# %%
# Establish the Python Logger  
import logging # built in python library that does not need to be installed 
import quick_logger as ql

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_start(solution_name, start_time) 
ql.set_speaking_log(False)
ql.set_speaking_steps(False)
ql.pvlog('info',f'Process {solution_name} Step 0 - Initializing and starting Logging Process.')
# Out:
# Process solution_registry Step 0 - Initializing and starting Logging Process.

# %%
full_path_to_registry_filename = "C://users//josep//solution_registry//solution_registry.xlsx"
df_solution_registry = pd.read_excel(full_path_to_registry_filename, index_col=None) 
df_solution_registry = df_solution_registry.sort_values(by='solution_directory')
print(f"Found {df_solution_registry.shape[0]} solutions") 
df_solution_registry.head(3)
# Out:
# Found 108 solutions
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0                      solution_name  \
# 0             0             0           0                Archival Automation
# 1             1             1           1     Automated Application Launcher
# 2            87            87           2  automating_windows_task_scheduler
#
#                   solution_directory  \
# 0                archival_automation
# 1     automated_application_launcher
# 2  automating_windows_task_scheduler
#
#                                  solution_definition  \
# 0  Archival Automation automatically backs up you...
# 1  Automated Application Launcher launches any ap...
# 2  This solution automates creating python script...
#
#                                 solution_description
# 0  Archival Automation automatically backs up you...
# 1  Automated Application Launcher launches any ap...
# 2  This solution automates creating python script...

# %%
df_solution_registry = df_solution_registry.drop_duplicates()
full_path_to_registry_filename = "C://users//josep//solution_registry//solution_registry.xlsx"
df_solution_registry.to_excel(full_path_to_registry_filename, index=False)
full_path_to_registry_filename = "C://users//josep//solution_registry//solution_registry.parquet"
df_solution_registry.to_parquet(full_path_to_registry_filename, index=False)

# %%
def print_solution_list(df):
    for idx, row in enumerate(df.itertuples(), start=1):
        print(f"{idx}. Name: {row.solution_name}, Solution Directory: {row.solution_directory}")

# Print the enumerated list of solutions
print_solution_list(df_solution_registry)
# Out:
# 1. Name: Archival Automation, Solution Directory: archival_automation
# 2. Name: Automated Application Launcher, Solution Directory: automated_application_launcher
# 3. Name: automating_windows_task_scheduler, Solution Directory: automating_windows_task_scheduler
# 4. Name: Calculator, Solution Directory: calculator
# 5. Name: Cancer Care Timeline, Solution Directory: cancer_care_timeline
# 6. Name: cancer_care_timeline, Solution Directory: cancer_care_timeline
# 7. Name: cancer_classification, Solution Directory: cancer_classification
# 8. Name: cancer_staging, Solution Directory: cancer_staging
# 9. Name: cancer_survival_index, Solution Directory: cancer_survival_index
# 10. Name: cancer_treatment_modalities, Solution Directory: cancer_treatment_modalities
# 11. Name: Cancer Treatment Outcomes, Solution Directory: cancer_treatment_outcomes
# 12. Name: cancer_treatment_sequencing, Solution Directory: cancer_treatment_sequencing
# 13. Name: Cancer Treatment Side Effects, Solution Directory: cancer_treatment_side_effects
# 14. Name: Chat Gpt Integration, Solution Directory: chat_gpt_integration
# 15. Name: Chronic Disease Registry, Solution Directory: chronic_disease_registry
# 16. Name: Clinical Classification System, Solution Directory: clinical_classification_system
# 17. Name: Configuring Settings, Solution Directory: configuring_settings
# 18. Name: Convert MS Access to New Technology, Solution Directory: convert_msaccess
# 19. Name: Corpus, Solution Directory: corpus
# 20. Name: corpus_learning_chatbot, Solution Directory: corpus_learning_chatbot
# 21. Name: Correlation Heatmap, Solution Directory: correlation_heatmap
# 22. Name: Create Readme Md, Solution Directory: create_readme_md
# 23. Name: create_solution, Solution Directory: create_solution
# 24. Name: Curated Datasets, Solution Directory: curated_datasets
# 25. Name: Daily Data Loader  , Solution Directory: daily_data_loader
# 26. Name: Data Cleansing, Solution Directory: data_cleansing
# 27. Name: Data Delta Calculator, Solution Directory: data_delta_calculator
# 28. Name: Data Discovery, Solution Directory: data_discovery
# 29. Name: Data Loader Reference Tables , Solution Directory: data_loader_reference_tables
# 30. Name: Data Loader Transactional  Tables , Solution Directory: data_loader_transactional__tables
# 31. Name: Data Profiling, Solution Directory: data_profiling
# 32. Name: Data Sets, Solution Directory: data_sets
# 33. Name: Design Goals , Solution Directory: design_goal
# 34. Name: Diabetes Outcome Analysis, Solution Directory: diabetes_outcome_analysis
# 35. Name: Diabetes Risk Stratification., Solution Directory: diabetes_risk_stratification
# 36. Name: diagrams, Solution Directory: diagrams
# 37. Name: Disease Progression Model, Solution Directory: disease_progression_model
# 38. Name: Email Automation, Solution Directory: email_automation
# 39. Name: Environment Testing , Solution Directory: environment_testing
# 40. Name: Epidemiology Methodology, Solution Directory: epidemiology_methodology
# 41. Name: File Discovery, Solution Directory: file_discovery
# 42. Name: File Manager, Solution Directory: file_manager
# 43. Name: File Removal, Solution Directory: file_removal
# 44. Name: File Watchdog, Solution Directory: file_watchdog
# 45. Name: Form Validator, Solution Directory: form_validator
# 46. Name: Git Commands, Solution Directory: git_commands
# 47. Name: Github Automation, Solution Directory: github_automation
# 48. Name: Glossary Term , Solution Directory: glossary_term
# 49. Name: Happiness Datasets, Solution Directory: happiness_datasets
# 50. Name: High Risk High Need, Solution Directory: high_risk_high_need
# 51. Name: Hugging Face Transformers, Solution Directory: hugging_face_transformers
# 52. Name: icd_10_cm_analysis, Solution Directory: icd_10_cm_analysis
# 53. Name: Incremental Imports, Solution Directory: incremental_imports
# 54. Name: Infrastructure Setup, Solution Directory: infrastructure_setup
# 55. Name: Intelligent Chatbot Corpus Learning , Solution Directory: intelligent_chatbot_corpus_learning
# 56. Name: Intelligent Chatbot Data Serialization , Solution Directory: intelligent_chatbot_data_serialization
# 57. Name: Intelligent Chatbot Generative Digital Assistant , Solution Directory: intelligent_chatbot_generative_digital_assistant
# 58. Name: Intelligent Chatbot Web Scrapping  , Solution Directory: intelligent_chatbot_web_scrapping
# 59. Name: inventory_your_python, Solution Directory: inventory_your_python
# 60. Name: Jupyter Notebook Process Steps, Solution Directory: jupyter_notebook_process_steps
# 61. Name: Kids Abc Book, Solution Directory: kids_abc_book
# 62. Name: Library Installer, Solution Directory: library_installer
# 63. Name: Logging And Debugging, Solution Directory: logging_and_debugging
# 64. Name: Managing Personas, Solution Directory: managing_personas
# 65. Name: Membership Matching, Solution Directory: membership_matching
# 66. Name: Multi Disciplinary Cancer Care Team, Solution Directory: multi_disciplinary_cancer_care_team
# 67. Name: multi_disciplinary_cancer_care_team, Solution Directory: multi_disciplinary_cancer_care_team
# 68. Name: Notebook Clone, Solution Directory: notebook_clone
# 69. Name: oncology_diagnostic_coding, Solution Directory: oncology_diagnostic_coding
# 70. Name: oncology_epidemiology, Solution Directory: oncology_epidemiology
# 71. Name: Oncology Procedures Classification, Solution Directory: oncology_procedures_classification
# 72. Name: Oncology Terminology, Solution Directory: oncology_terminology
# 73. Name: Patient Cancer Risk Index, Solution Directory: patient_cancer_risk_index
# 74. Name: patient_cancer_risk_index, Solution Directory: patient_cancer_risk_index
# 75. Name: Patient Complexity Index , Solution Directory: patient_complexity_index
# 76. Name: patient_gaps_in_care, Solution Directory: patient_gaps_in_care
# 77. Name: Patient Word Cloud, Solution Directory: patient_word_cloud
# 78. Name: Penguins, Solution Directory: penguins
# 79. Name: Poor Emotional Regulatory Control , Solution Directory: poor_emotional_regulatory_control
# 80. Name: Precision Oncology, Solution Directory: precision_oncology
# 81. Name: Predicting Colorectal Cancer, Solution Directory: predicting_colorectal_cancer
# 82. Name: Predicting Diabetes, Solution Directory: predicting_diabetes
# 83. Name: Predicting Lung Cancer, Solution Directory: predicting_lung_cancer
# 84. Name: Principal Component Analysis, Solution Directory: principal_component_analysis
# 85. Name: Progress Bar, Solution Directory: progress_bar
# 86. Name: Python Foundation, Solution Directory: python_foundation
# 87. Name: quality_of_life_index, Solution Directory: quality_of_life_index
# 88. Name: Library for Logging And Debugging, Solution Directory: quicklogging
# 89. Name: Remote Process Automation Excel, Solution Directory: remote_process_automation_excel
# 90. Name: Rules Engine, Solution Directory: rules_engine
# 91. Name: Simple Chatbot Simple Nlp Response, Solution Directory: simple_chatbot_simple_nlp_response
# 92. Name: Smart Mini Proposal, Solution Directory: smart_mini_proposal
# 93. Name: Solution Registry , Solution Directory: solution_registry
# 94. Name: Solution Template, Solution Directory: solution_template
# 95. Name: SQLite Introduction, Solution Directory: sqlite_introduction
# 96. Name: System Information, Solution Directory: system_information
# 97. Name: taipy_web_gui, Solution Directory: taipy_web_gui
# 98. Name: Talking Code, Solution Directory: talking_code
# 99. Name: Talking Code Library , Solution Directory: talkingcode
# 100. Name: Task Scheduling, Solution Directory: task_scheduling
# 101. Name: term_frequency_inverse_document_frequency, Solution Directory: term_frequency_inverse_document_frequency
# 102. Name: titanic_survival_analysis, Solution Directory: titanic_survival_analysis
# 103. Name: Unzip Automation, Solution Directory: unzip_automation
# 104. Name: Update Solution Images, Solution Directory: update_solution_images
# 105. Name: Updating Libraries, Solution Directory: updating_libraries
# 106. Name: Web Automation, Solution Directory: web_automation
# 107. Name: Word Cloud, Solution Directory: word_cloud
# 108. Name: World Mood, Solution Directory: world_mood

# %%
definition = '''
A **solution registry** for Artificial Intelligence (AI) busines solutions serves as a centralized database containing names, directories, and brief descriptions of various AI solutions. This registry facilitates easy access to a wide range of AI solutions, allowing businesses and individuals to quickly identify relevant tools for their needs. Moreover, maintaining such a registry ensures up-to-date information on emerging AI technologies, fosters collaboration and knowledge sharing among developers, and streamlines the process of researching and adopting AI solutions. With proper organization and regular updates, the registry offers a comprehensive resource that enhances decision-making and accelerates innovation in the AI ecosystem.
''' 
# Write the solution defitions out to the solution_description.md file
file_name = "solution_description.md"
with open(file_name, 'w') as f:
    # Write the template to the readme.md file
     f.write(definition)

talking_code = False
if talking_code:
    tc.print_say(definition) 
else:
    print(definition)
# Out:
# A **solution registry** for Artificial Intelligence (AI) busines solutions serves as a centralized database containing names, directories, and brief descriptions of various AI solutions. This registry facilitates easy access to a wide range of AI solutions, allowing businesses and individuals to quickly identify relevant tools for their needs. Moreover, maintaining such a registry ensures up-to-date information on emerging AI technologies, fosters collaboration and knowledge sharing among developers, and streamlines the process of researching and adopting AI solutions. With proper organization and regular updates, the registry offers a comprehensive resource that enhances decision-making and accelerates innovation in the AI ecosystem.

# %% [markdown]
# ## Step 0 - Process End - display log

# %%
# Calculate and classify the process performance 
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))
# Out:
# 2024-04-27 17:02:07,684 - INFO - START solution_registry =============================================
# 2024-04-27 17:02:07,684 - INFO - START solution_registry Start Time = 2024-04-27 17:02:07
# 2024-04-27 17:02:07,684 - INFO - solution_registry Step 0 - Initialize the configuration file parser
# 2024-04-27 17:02:07,685 - INFO - Process solution_registry Step 0 - Initializing and starting Logging Process.
# 2024-04-27 17:02:08,244 - INFO - PERFORMANCE solution_registry The total process duration was:0.56
# 2024-04-27 17:02:08,244 - INFO - PERFORMANCE solution_registry Stop Time = 2024-04-27 17:02:08
# 2024-04-27 17:02:08,244 - INFO - PERFORMANCE solution_registry Short process duration less than 3 Seconds:0.56
# 2024-04-27 17:02:08,245 - INFO - PERFORMANCE solution_registry Performance optimization is not reccomended
# 2024-04-27 17:02:08,245 - INFO - END solution_registry =============================================

# %% [markdown]
# #### https://github.com/JoeEberle/ -- josepheberle@outlook.com
